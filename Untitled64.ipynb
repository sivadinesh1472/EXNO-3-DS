# %%
import pandas as pd
df=pd.read_csv("Encoding Data.csv")
df
# Out:
#    id bin_1 bin_2  nom_0 ord_2
# 0   0     F     N    Red   Hot
# 1   1     F     Y   Blue  Warm
# 2   2     F     N   Blue  Cold
# 3   3     F     N  Green  Warm
# 4   4     T     N    Red  Cold
# 5   5     T     N  Green   Hot
# 6   6     F     N    Red  Cold
# 7   7     T     N    Red  Cold
# 8   8     F     N   Blue  Warm
# 9   9     F     Y    Red   Hot

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\admin\.conda\envs\opencv\lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
pm=['Hot','Warm','Cold']
e1=OrdinalEncoder(categories=[pm])
e1.fit_transform(df[["ord_2"]])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [2.],
#        [1.],
#        [0.]])

# %%
df['bo2']=e1.fit_transform(df[["ord_2"]])
df
# Out:
#    id bin_1 bin_2  nom_0 ord_2  bo2
# 0   0     F     N    Red   Hot  0.0
# 1   1     F     Y   Blue  Warm  1.0
# 2   2     F     N   Blue  Cold  2.0
# 3   3     F     N  Green  Warm  1.0
# 4   4     T     N    Red  Cold  2.0
# 5   5     T     N  Green   Hot  0.0
# 6   6     F     N    Red  Cold  2.0
# 7   7     T     N    Red  Cold  2.0
# 8   8     F     N   Blue  Warm  1.0
# 9   9     F     Y    Red   Hot  0.0

# %%
le=LabelEncoder()
dfc=df.copy()
dfc['ord_2']=le.fit_transform(dfc['ord_2'])
dfc
# Out:
#    id bin_1 bin_2  nom_0  ord_2  bo2
# 0   0     F     N    Red      1  0.0
# 1   1     F     Y   Blue      2  1.0
# 2   2     F     N   Blue      0  2.0
# 3   3     F     N  Green      2  1.0
# 4   4     T     N    Red      0  2.0
# 5   5     T     N  Green      1  0.0
# 6   6     F     N    Red      0  2.0
# 7   7     T     N    Red      0  2.0
# 8   8     F     N   Blue      2  1.0
# 9   9     F     Y    Red      1  0.0

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

one = OneHotEncoder(sparse_output=False)   # <-- use sparse_output
df2 = df.copy()
enc = pd.DataFrame(one.fit_transform(df2[["nom_0"]]))
df2 = pd.concat([df2, enc], axis=1)
df2
# Out:
#    id bin_1 bin_2  nom_0 ord_2  bo2    0    1    2
# 0   0     F     N    Red   Hot  0.0  0.0  0.0  1.0
# 1   1     F     Y   Blue  Warm  1.0  1.0  0.0  0.0
# 2   2     F     N   Blue  Cold  2.0  1.0  0.0  0.0
# 3   3     F     N  Green  Warm  1.0  0.0  1.0  0.0
# 4   4     T     N    Red  Cold  2.0  0.0  0.0  1.0
# 5   5     T     N  Green   Hot  0.0  0.0  1.0  0.0
# 6   6     F     N    Red  Cold  2.0  0.0  0.0  1.0
# 7   7     T     N    Red  Cold  2.0  0.0  0.0  1.0
# 8   8     F     N   Blue  Warm  1.0  1.0  0.0  0.0
# 9   9     F     Y    Red   Hot  0.0  0.0  0.0  1.0

# %%
pd.get_dummies(df2,columns=["nom_0"])
# Out:
#    id bin_1 bin_2 ord_2  bo2    0    1    2  nom_0_Blue  nom_0_Green  \
# 0   0     F     N   Hot  0.0  0.0  0.0  1.0       False        False
# 1   1     F     Y  Warm  1.0  1.0  0.0  0.0        True        False
# 2   2     F     N  Cold  2.0  1.0  0.0  0.0        True        False
# 3   3     F     N  Warm  1.0  0.0  1.0  0.0       False         True
# 4   4     T     N  Cold  2.0  0.0  0.0  1.0       False        False
# 5   5     T     N   Hot  0.0  0.0  1.0  0.0       False         True
# 6   6     F     N  Cold  2.0  0.0  0.0  1.0       False        False
# 7   7     T     N  Cold  2.0  0.0  0.0  1.0       False        False
# 8   8     F     N  Warm  1.0  1.0  0.0  0.0        True        False
# 9   9     F     Y   Hot  0.0  0.0  0.0  1.0       False        False
#
#    nom_0_Red
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6       True
# 7       True
# 8      False
# 9       True

# %%
pip install --upgrade category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from category_encoders) (2.2.6)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from category_encoders) (3.0.0)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from category_encoders) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from category_encoders) (1.17.0)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Downloading statsmodels-0.14.6-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\admin\.conda\envs\opencv\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\.conda\envs\opencv\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Downloading category_encoders-2.9.0-py3-none-any.whl (85 kB)
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading statsmodels-0.14.6-cp311-cp311-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.6 MB 5.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.6 MB 4.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.6 MB 6.3 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.6 MB 5.9 MB/s eta 0:00:01
#    --------------------------- ------------ 6.6/9.6 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 6.3 MB/s  0:00:01
# Installing collected packages: patsy, statsmodels, category_encoders
#
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    ------------- -------------------------- 1/3 [statsmodels]
#    -------------------------- ------------- 2/3 [category_encoders]
#    -------------------------- ------------- 2/3 [category_encoders]
#    -------------------------- ------------- 2/3 [category_encoders]
#    -------------------------- ------------- 2/3 [category_encoders]
#    -------------------------- ------------- 2/3 [category_encoders]
#    ---------------------------------------- 3/3 [category_encoders]
#
# Successfully installed category_encoders-2.9.0 patsy-1.0.2 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from category_encoders import BinaryEncoder
df=pd.read_csv("data.csv")
df
# Out:
#    id bin_1 bin_2       City     Ord_1        Ord_2  Target
# 0   0     F     N      Delhi       Hot  High School       0
# 1   1     F     Y  Bangalore      Warm      Masters       1
# 2   2     M     N     Mumbai  Very Hot      Diploma       1
# 3   3     M     Y    Chennai      Cold    Bachelors       0
# 4   4     M     Y      Delhi      Cold    Bachelors       1
# 5   5     F     N      Delhi  Very Hot      Masters       0
# 6   6     M     N    Chennai      Warm          PhD       1
# 7   7     F     N    Chennai       Hot  High School       1
# 8   8     M     N      Delhi  Very Hot  High School       0
# 9   9     F     Y      Delhi      Warm          PhD       0

# %%
be=BinaryEncoder()
nd=be.fit_transform(df['Ord_2'])
df
# Out:
#    id bin_1 bin_2       City     Ord_1        Ord_2  Target
# 0   0     F     N      Delhi       Hot  High School       0
# 1   1     F     Y  Bangalore      Warm      Masters       1
# 2   2     M     N     Mumbai  Very Hot      Diploma       1
# 3   3     M     Y    Chennai      Cold    Bachelors       0
# 4   4     M     Y      Delhi      Cold    Bachelors       1
# 5   5     F     N      Delhi  Very Hot      Masters       0
# 6   6     M     N    Chennai      Warm          PhD       1
# 7   7     F     N    Chennai       Hot  High School       1
# 8   8     M     N      Delhi  Very Hot  High School       0
# 9   9     F     Y      Delhi      Warm          PhD       0

# %%
dfb=pd.concat([df,nd],axis=1)
dfb
# Out:
#    id bin_1 bin_2       City     Ord_1        Ord_2  Target  Ord_2_0  Ord_2_1  \
# 0   0     F     N      Delhi       Hot  High School       0        0        0
# 1   1     F     Y  Bangalore      Warm      Masters       1        0        1
# 2   2     M     N     Mumbai  Very Hot      Diploma       1        0        1
# 3   3     M     Y    Chennai      Cold    Bachelors       0        1        0
# 4   4     M     Y      Delhi      Cold    Bachelors       1        1        0
# 5   5     F     N      Delhi  Very Hot      Masters       0        0        1
# 6   6     M     N    Chennai      Warm          PhD       1        1        0
# 7   7     F     N    Chennai       Hot  High School       1        0        0
# 8   8     M     N      Delhi  Very Hot  High School       0        0        0
# 9   9     F     Y      Delhi      Warm          PhD       0        1        0
#
#    Ord_2_2
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
# 5        0
# 6        1
# 7        1
# 8        1
# 9        1

# %%
from category_encoders import TargetEncoder
te=TargetEncoder()
CC=df.copy()
new=te.fit_transform(X=CC["City"],y=CC["Target"])
CC=pd.concat([CC,new],axis=1)
CC
# Out:
#    id bin_1 bin_2       City     Ord_1        Ord_2  Target      City
# 0   0     F     N      Delhi       Hot  High School       0  0.445272
# 1   1     F     Y  Bangalore      Warm      Masters       1  0.565054
# 2   2     M     N     Mumbai  Very Hot      Diploma       1  0.565054
# 3   3     M     Y    Chennai      Cold    Bachelors       0  0.525744
# 4   4     M     Y      Delhi      Cold    Bachelors       1  0.445272
# 5   5     F     N      Delhi  Very Hot      Masters       0  0.445272
# 6   6     M     N    Chennai      Warm          PhD       1  0.525744
# 7   7     F     N    Chennai       Hot  High School       1  0.525744
# 8   8     M     N      Delhi  Very Hot  High School       0  0.445272
# 9   9     F     Y      Delhi      Warm          PhD       0  0.445272

# %%
import pandas as pd
from scipy import stats
import numpy as np
df=pd.read_csv("Data_to_Transform.csv")
df
# Out:
#       Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                   0.899990              2.895074               11.180748
# 1                   1.113554              2.962385               10.842938
# 2                   1.156830              2.966378               10.817934
# 3                   1.264131              3.000324               10.764570
# 4                   1.323914              3.012109               10.753117
# ...                      ...                   ...                     ...
# 9995               14.749050             16.289513               -2.980821
# 9996               14.854474             16.396252               -3.147526
# 9997               15.262103             17.102991               -3.517256
# 9998               15.269983             17.628467               -4.689833
# 9999               16.204517             18.052331               -6.335679
#
#       Highly Negative Skew
# 0                 9.027485
# 1                 9.009762
# 2                 9.006134
# 3                 9.000125
# 4                 8.981296
# ...                    ...
# 9995             -3.254882
# 9996             -3.772332
# 9997             -4.717950
# 9998             -5.670496
# 9999             -7.036091
#
# [10000 rows x 4 columns]

# %%
df.skew()
# Out:
# Moderate Positive Skew    0.656308
# Highly Positive Skew      1.271249
# Moderate Negative Skew   -0.690244
# Highly Negative Skew     -1.201891
# dtype: float64

# %%
np.log(df["Highly Positive Skew"])
# Out:
# 0       1.063011
# 1       1.085995
# 2       1.087342
# 3       1.098720
# 4       1.102640
#           ...
# 9995    2.790522
# 9996    2.797053
# 9997    2.839253
# 9998    2.869515
# 9999    2.893275
# Name: Highly Positive Skew, Length: 10000, dtype: float64

# %%
np.sqrt(df["Highly Positive Skew"])
# Out:
# 0       1.701492
# 1       1.721158
# 2       1.722317
# 3       1.732144
# 4       1.735543
#           ...
# 9995    4.036027
# 9996    4.049229
# 9997    4.135576
# 9998    4.198627
# 9999    4.248803
# Name: Highly Positive Skew, Length: 10000, dtype: float64

# %%
np.reciprocal(df["Moderate Positive Skew"])
# Out:
# 0       1.111123
# 1       0.898026
# 2       0.864431
# 3       0.791057
# 4       0.755336
#           ...
# 9995    0.067801
# 9996    0.067320
# 9997    0.065522
# 9998    0.065488
# 9999    0.061711
# Name: Moderate Positive Skew, Length: 10000, dtype: float64

# %%
np.square(df["Highly Positive Skew"])
# Out:
# 0         8.381452
# 1         8.775724
# 2         8.799396
# 3         9.001942
# 4         9.072800
#            ...
# 9995    265.348230
# 9996    268.837091
# 9997    292.512290
# 9998    310.762852
# 9999    325.886637
# Name: Highly Positive Skew, Length: 10000, dtype: float64

# %%
df["Highly Positive Skew_boxcox"], parameters=stats.boxcox(df["Highly Positive Skew"])
df
# Out:
#       Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                   0.899990              2.895074               11.180748
# 1                   1.113554              2.962385               10.842938
# 2                   1.156830              2.966378               10.817934
# 3                   1.264131              3.000324               10.764570
# 4                   1.323914              3.012109               10.753117
# ...                      ...                   ...                     ...
# 9995               14.749050             16.289513               -2.980821
# 9996               14.854474             16.396252               -3.147526
# 9997               15.262103             17.102991               -3.517256
# 9998               15.269983             17.628467               -4.689833
# 9999               16.204517             18.052331               -6.335679
#
#       Highly Negative Skew  Highly Positive Skew_boxcox
# 0                 9.027485                     0.812909
# 1                 9.009762                     0.825921
# 2                 9.006134                     0.826679
# 3                 9.000125                     0.833058
# 4                 8.981296                     0.835247
# ...                    ...                          ...
# 9995             -3.254882                     1.457701
# 9996             -3.772332                     1.459189
# 9997             -4.717950                     1.468681
# 9998             -5.670496                     1.475357
# 9999             -7.036091                     1.480525
#
# [10000 rows x 5 columns]

# %%
df.skew()
# Out:
# Moderate Positive Skew         0.656308
# Highly Positive Skew           1.271249
# Moderate Negative Skew        -0.690244
# Highly Negative Skew          -1.201891
# Highly Positive Skew_boxcox    0.023089
# dtype: float64

# %%
df["Highly Negative Skew_yeojohnson"],parameters=stats.yeojohnson(df["Highly Negative Skew"])
df.skew()
# Out:
# Moderate Positive Skew             0.656308
# Highly Positive Skew               1.271249
# Moderate Negative Skew            -0.690244
# Highly Negative Skew              -1.201891
# Highly Positive Skew_boxcox        0.023089
# Highly Negative Skew_yeojohnson   -0.274676
# dtype: float64

# %%
from sklearn.preprocessing import QuantileTransformer
qt=QuantileTransformer(output_distribution='normal')
df["Moderate Negative Skew_1"]=qt.fit_transform(df[["Moderate Negative Skew"]])
df
# Out:
#       Moderate Positive Skew  Highly Positive Skew  Moderate Negative Skew  \
# 0                   0.899990              2.895074               11.180748
# 1                   1.113554              2.962385               10.842938
# 2                   1.156830              2.966378               10.817934
# 3                   1.264131              3.000324               10.764570
# 4                   1.323914              3.012109               10.753117
# ...                      ...                   ...                     ...
# 9995               14.749050             16.289513               -2.980821
# 9996               14.854474             16.396252               -3.147526
# 9997               15.262103             17.102991               -3.517256
# 9998               15.269983             17.628467               -4.689833
# 9999               16.204517             18.052331               -6.335679
#
#       Highly Negative Skew  Highly Positive Skew_boxcox  \
# 0                 9.027485                     0.812909
# 1                 9.009762                     0.825921
# 2                 9.006134                     0.826679
# 3                 9.000125                     0.833058
# 4                 8.981296                     0.835247
# ...                    ...                          ...
# 9995             -3.254882                     1.457701
# 9996             -3.772332                     1.459189
# 9997             -4.717950                     1.468681
# 9998             -5.670496                     1.475357
# 9999             -7.036091                     1.480525
#
#       Highly Negative Skew_yeojohnson  Moderate Negative Skew_1
# 0                           51.081488                  5.199338
# 1                           50.898043                  3.227288
# 2                           50.860532                  3.206801
# 3                           50.798434                  3.167111
# 4                           50.604086                  3.159208
# ...                               ...                       ...
# 9995                        -1.433326                 -3.147619
# 9996                        -1.545673                 -3.162489
# 9997                        -1.722267                 -3.198205
# 9998                        -1.872430                 -3.350199
# 9999                        -2.053503                 -5.199338
#
# [10000 rows x 7 columns]

# %%
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
sm.qqplot(df["Moderate Negative Skew"],line='45')
plt.show()

# %%
sm.qqplot(np.reciprocal(df["Moderate Negative Skew"]),line='45')
plt.show()

# %%
from sklearn.preprocessing import QuantileTransformer
qt=QuantileTransformer(output_distribution='normal',n_quantiles=891)
df["Moderate Negative Skew"]=qt.fit_transform(df[["Moderate Negative Skew"]])
sm.qqplot(df["Moderate Negative Skew"],line='45')
plt.show()

# %%
df["Highly Negative Skew_1"]=qt.fit_transform(df[["Highly Negative Skew"]])
sm.qqplot(df["Highly Negative Skew"],line='45')
plt.show()

# %%
dt=pd.read_csv("data.csv")
dt
# Out:
#    id bin_1 bin_2       City     Ord_1        Ord_2  Target
# 0   0     F     N      Delhi       Hot  High School       0
# 1   1     F     Y  Bangalore      Warm      Masters       1
# 2   2     M     N     Mumbai  Very Hot      Diploma       1
# 3   3     M     Y    Chennai      Cold    Bachelors       0
# 4   4     M     Y      Delhi      Cold    Bachelors       1
# 5   5     F     N      Delhi  Very Hot      Masters       0
# 6   6     M     N    Chennai      Warm          PhD       1
# 7   7     F     N    Chennai       Hot  High School       1
# 8   8     M     N      Delhi  Very Hot  High School       0
# 9   9     F     Y      Delhi      Warm          PhD       0

# %%
from sklearn.preprocessing import QuantileTransformer
qt=QuantileTransformer(output_distribution='normal',n_quantiles=891)
dt["Ord_1"]=qt.fit_transform(dt[["Target"]])
sm.qqplot(dt['Target'],line='45')
plt.show()
# Out:
# C:\Users\admin\.conda\envs\opencv\Lib\site-packages\sklearn\preprocessing\_data.py:2885: UserWarning: n_quantiles (891) is greater than the total number of samples (10). n_quantiles is set to n_samples.
#   warnings.warn(

# %%
sm.qqplot(df["Highly Negative Skew_1"],line='45')
plt.show()
